# %%
from regressor import Regressor
import matplotlib.pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
inputs, labels = make_blobs(n_samples=400, n_features=2, centers=2, cluster_std=2.5, random_state=95)
plt.scatter(inputs[:, 0], inputs[:, 1], c=labels)

# %%
regressor = Regressor(2)
print(regressor.weights)
# Out:
# [0.19714319 0.11408981 0.87576474]

# %%
regressor.sgd(inputs, labels, batch_size=1, lr=10)
regressor.sgd(inputs, labels, batch_size=1, lr=10)

# %%
regressor.weights
# Out:
# array([ 1.70145601,  2.68959119, 14.04267738])

# %%
regressor.plot_loss()
